# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_variable_Pie(data_table, variable):
 #准备绘图数据
 data = data_table[variable].value_counts()

#创建饼图
fig1, ax1 = plt.subplots()
ax1.pie(data, labels = data.index, autopct='%1.1f%%')
ax1.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle


plt.title('Pie Chart of' + variable)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\韦亚琦\Desktop\3289834600\text.ipynb 单元格 1 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/%E9%9F%A6%E4%BA%9A%E7%90%A6/Desktop/3289834600/text.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> #创建饼图
#       <a href='vscode-notebook-cell:/c%3A/Users/%E9%9F%A6%E4%BA%9A%E7%90%A6/Desktop/3289834600/text.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> fig1, ax1 = plt.subplots()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/%E9%9F%A6%E4%BA%9A%E7%90%A6/Desktop/3289834600/text.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a> ax1.pie(data, labels = data.index, autopct='%1.1f%%')
#      <a href='vscode-notebook-cell:/c%3A/Users/%E9%9F%A6%E4%BA%9A%E7%90%A6/Desktop/3289834600/text.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> ax1.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle
#      <a href='vscode-notebook-cell:/c%3A/Users/%E9%9F%A6%E4%BA%9A%E7%90%A6/Desktop/3289834600/text.ipynb#W0sZmlsZQ%3D%3D?line=13'>14</a> plt.title('Pie Chart of' + variable)
#
# NameError: name 'data' is not defined

# %%
import mytools
df2,meta = mytools.读取SPSS数据(R'data/identity.sav')
plot_variable_Pie(df2,'年级')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\韦亚琦\Desktop\3289834600\text.ipynb 单元格 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/%E9%9F%A6%E4%BA%9A%E7%90%A6/Desktop/3289834600/text.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import mytools
#       <a href='vscode-notebook-cell:/c%3A/Users/%E9%9F%A6%E4%BA%9A%E7%90%A6/Desktop/3289834600/text.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df2,meta = mytools.读取SPSS数据(R'data/identity.sav')
#       <a href='vscode-notebook-cell:/c%3A/Users/%E9%9F%A6%E4%BA%9A%E7%90%A6/Desktop/3289834600/text.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> plot_variable_Pie(df2,'年级')
#
# File c:\Users\韦亚琦\Desktop\3289834600\mytools.py:20
#      18 fig, ax = plt.subplots()
#      19 # 绘制柱状图
# ---> 20 rects1 = ax.bar(x, y)
#      21 # 设置x轴变量名称
#      22 ax.set_xlabel(ymax=100)
#
# NameError: name 'x' is not defined

# %%
df2['年级'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\韦亚琦\Desktop\3289834600\text.ipynb 单元格 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/%E9%9F%A6%E4%BA%9A%E7%90%A6/Desktop/3289834600/text.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> df2['年级'].value_counts()
#
# NameError: name 'df2' is not defined
